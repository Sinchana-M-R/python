# %%
import pandas as pd
df=pd.read_csv("day_wise.csv",index_col='Date',parse_dates=True)
df.head(10)
# Out:
#             Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# Date
# 2020-01-22        555      17         28     510          0           0
# 2020-01-23        654      18         30     606         99           1
# 2020-01-24        941      26         36     879        287           8
# 2020-01-25       1434      42         39    1353        493          16
# 2020-01-26       2118      56         52    2010        684          14
# 2020-01-27       2927      82         61    2784        809          26
# 2020-01-28       5578     131        107    5340       2651          49
# 2020-01-29       6166     133        125    5908        588           2
# 2020-01-30       8234     171        141    7922       2068          38
# 2020-01-31       9927     213        219    9495       1693          42
#
#             New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# Date
# 2020-01-22              0                3.06                   5.05
# ...

# %%
result=df.columns
print(result)
# Out:
# Index(['Confirmed', 'Deaths', 'Recovered', 'Active', 'New cases', 'New deaths',
#        'New recovered', 'Deaths / 100 Cases', 'Recovered / 100 Cases',
#        'Deaths / 100 Recovered', 'No. of countries'],
#       dtype='object')

# %%
df.dropna(inplace=True)
large5=df.nlargest(5,"Confirmed")
print(large5)
# Out:
#             Confirmed  Deaths  Recovered   Active  New cases  New deaths  \
# Date
# 2020-07-27   16480485  654036    9468087  6358362     228693        5415
# 2020-07-26   16251796  648621    9293464  6309711     204606        4104
# 2020-07-25   16047190  644517    9158743  6243930     255545        4867
# 2020-07-24   15791645  639650    8939705  6212290     281164        6144
# 2020-07-23   15510481  633506    8710969  6166006     282756        9966
#
#             New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# Date
# 2020-07-27         174623                3.97                  57.45
# 2020-07-26         134721                3.99                  57.18
# 2020-07-25         219038                4.02                  57.07
# 2020-07-24         228736                4.05                  56.61
# 2020-07-23         169714                4.08                  56.16
#
#             Deaths / 100 Recovered  No. of countries
# Date
# ...

# %%
df.sort_values(by=["Recovered"])
# Out:
#             Confirmed  Deaths  Recovered   Active  New cases  New deaths  \
# Date
# 2020-01-22        555      17         28      510          0           0
# 2020-01-23        654      18         30      606         99           1
# 2020-01-24        941      26         36      879        287           8
# 2020-01-25       1434      42         39     1353        493          16
# 2020-01-26       2118      56         52     2010        684          14
# ...               ...     ...        ...      ...        ...         ...
# 2020-07-23   15510481  633506    8710969  6166006     282756        9966
# 2020-07-24   15791645  639650    8939705  6212290     281164        6144
# 2020-07-25   16047190  644517    9158743  6243930     255545        4867
# 2020-07-26   16251796  648621    9293464  6309711     204606        4104
# 2020-07-27   16480485  654036    9468087  6358362     228693        5415
#
#             New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# Date
# ...

# %%
df.skew(skipna = True)
# Out:
# Confirmed                 0.928070
# Deaths                    0.378594
# Recovered                 1.266406
# Active                    0.504207
# New cases                 0.627127
# New deaths               -0.126165
# New recovered             1.303824
# Deaths / 100 Cases       -0.144540
# Recovered / 100 Cases    -0.431283
# Deaths / 100 Recovered    3.042263
# No. of countries         -1.138638
# dtype: float64

# %%
df.sem()
# Out:
# Confirmed                 347011.963096
# Deaths                     15894.112735
# Recovered                 191664.877255
# Active                    143652.981693
# New cases                   5491.473655
# New deaths                   185.083395
# New recovered               4090.848777
# Deaths / 100 Cases             0.115200
# Recovered / 100 Cases          1.181956
# Deaths / 100 Recovered         1.645963
# No. of countries               4.753447
# dtype: float64

# %%
result = df.truncate(before = '2020-02-02', after = '2020-02-08')

# Print the result
print(result)
# Out:
#             Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# Date
# 2020-02-02      16787     362        459   15966       4749         103
# 2020-02-03      19887     426        604   18857       3100          64
# 2020-02-04      23898     492        821   22585       4011          66
# 2020-02-05      27643     564       1071   26008       3745          72
# 2020-02-06      30802     634       1418   28750       3159          70
# 2020-02-07      34334     719       1903   31712       3532          85
# 2020-02-08      37068     806       2470   33792       2734          87
#
#             New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# Date
# 2020-02-02            178                2.16                   2.73
# 2020-02-03            145                2.14                   3.04
# 2020-02-04            217                2.06                   3.44
# 2020-02-05            250                2.04                   3.87
# ...

# %%
result = df.transform(func = lambda x : x - 10)

# Print the result
print(result)
# Out:
#             Confirmed  Deaths  Recovered   Active  New cases  New deaths  \
# Date
# 2020-01-22        545       7         18      500        -10         -10
# 2020-01-23        644       8         20      596         89          -9
# 2020-01-24        931      16         26      869        277          -2
# 2020-01-25       1424      32         29     1343        483           6
# 2020-01-26       2108      46         42     2000        674           4
# ...               ...     ...        ...      ...        ...         ...
# 2020-07-23   15510471  633496    8710959  6165996     282746        9956
# 2020-07-24   15791635  639640    8939695  6212280     281154        6134
# 2020-07-25   16047180  644507    9158733  6243920     255535        4857
# 2020-07-26   16251786  648611    9293454  6309701     204596        4094
# 2020-07-27   16480475  654026    9468077  6358352     228683        5405
#
#             New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# Date
# ...

# %%
df["Rank"] = df["Confirmed"].rank()

# display
df
df["Rank"] = df["Confirmed"].rank(method ='average')

# display
df
# Out:
#             Confirmed  Deaths  Recovered   Active  New cases  New deaths  \
# Date
# 2020-01-22        555      17         28      510          0           0
# 2020-01-23        654      18         30      606         99           1
# 2020-01-24        941      26         36      879        287           8
# 2020-01-25       1434      42         39     1353        493          16
# 2020-01-26       2118      56         52     2010        684          14
# ...               ...     ...        ...      ...        ...         ...
# 2020-07-23   15510481  633506    8710969  6166006     282756        9966
# 2020-07-24   15791645  639650    8939705  6212290     281164        6144
# 2020-07-25   16047190  644517    9158743  6243930     255545        4867
# 2020-07-26   16251796  648621    9293464  6309711     204606        4104
# 2020-07-27   16480485  654036    9468087  6358362     228693        5415
#
#             New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# Date
# ...

# %%
import plotly.express as px
fig = px.box(df,y="Deaths")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import seaborn as sns
from matplotlib import pyplot as plt
df.head()
sns.lineplot(x="New cases",y="New deaths",hue="No. of countries",data=df,style="No. of countries",marker=True)
sns.set(style="whitegrid")
plt.show()

# %%
sns.scatterplot(x="New cases",y="New deaths",data=df)
sns.set(style="whitegrid")

# %%
df["Confirmed"].mean()
# Out:
# 4406960.010638298

# %%
df["Deaths"].mean()
# Out:
# 230770.76063829788

# %%
df["Recovered"].mean()
# Out:
# 2066001.2180851065

# %%
df["Active"].mean()
# Out:
# 2110188.0319148935

# %%
df["New cases"].mean()
# Out:
# 87771.02127659574

# %%
from matplotlib import pyplot as plt
import numpy as np


# Creating dataset
Plot= ['Confirmed', 'Deaths', 'Recovered',
        'Active', 'New cases']

data = [4406960.010638298,230770.76063829788,2066001.2180851065,2110188.0319148935,87771.02127659574]

# Creating plot
fig = plt.figure(figsize=(10, 7))
plt.pie(data, labels=Plot)

# show plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


# Creating dataset
Plot= ['Confirmed', 'Deaths', 'Recovered',
        'Active', 'New cases']
data = [4406960.010638298,230770.76063829788,2066001.2180851065,2110188.0319148935,87771.02127659574]




# Creating explode data
# Creating color parameters
colors = ("pink", "yellow", "red",
          "black", "purple")

# Wedge properties
wp = {'linewidth': 1, 'edgecolor': "green"}

# Creating autocpt arguments


def func(pct, allvalues):
    absolute = int(pct / 100.*np.sum(allvalues))
    return "{:.1f}%\n({:d} g)".format(pct, absolute)


# Creating plot
fig, ax = plt.subplots(figsize=(10, 7))
wedges, texts, autotexts = ax.pie(data,
                                  autopct=lambda pct: func(pct, data),
                                  labels=Plot,
                                  shadow=True,
                                  colors=colors,
                                  startangle=90,
                                  wedgeprops=wp,
                                  textprops=dict(color="magenta"))

# Adding legend
ax.legend(wedges, Plot,
          title="Graph",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=8, weight="bold")
ax.set_title("Customizing pie chart")

# show plot
plt.show()
